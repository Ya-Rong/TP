# %% [markdown]
# 文字探勘

# %%
import jieba
import jieba.analyse
import pandas as pd
import numpy as np
import re
from collections import Counter

# %%
# 讀取從 pandas 來的結構化資料，但內文的句子尚未擷取出合適斷詞
orgdata = pd.read_csv('crawler_0323.csv', encoding = "UTF-8")

# %%
orgdata.head()
# Out:
#                                    title  \
# 0  Gogoro 與 foodpanda 合作，將於新加坡推行電動機車換電系統
# 1            團隊協作新的想像，微軟推出激似 Notion 的新工具
# 2             看好生成式 AI 潛力，中華電有望從客戶服務切入應用
# 3             童子賢：AI 還在中學階段未成熟，取代哪些產業不可知
# 4                全球首枚 3D 列印火箭成功發射，惜未進入軌道
#
#                                                  seg
# 0  ['Gogoro', 'foodpanda', '將於', '電動', '機車換', '電系...
# 1  ['團隊', '協作', '微軟', '激似', 'Notion', '想像', '工具',...
# 2  ['生成式', 'AI', '潛力', '中華電', '客戶', '服務', '應用', '...
# 3  ['AI', '還在', '中學階段', '未成熟', '童子', '可知', '哪些', ...
# 4   ['列印', '首枚', '3D', '發射', '進入', '軌道', '火箭', '成功']

# %%
orgdata['seg'] = ""
orgdata.head()
# Out:
#                                    title seg
# 0  Gogoro 與 foodpanda 合作，將於新加坡推行電動機車換電系統
# 1            團隊協作新的想像，微軟推出激似 Notion 的新工具
# 2             看好生成式 AI 潛力，中華電有望從客戶服務切入應用
# 3             童子賢：AI 還在中學階段未成熟，取代哪些產業不可知
# 4                全球首枚 3D 列印火箭成功發射，惜未進入軌道

# %%
jieba.analyse.set_stop_words('stopwords.txt') #stopwords 自己不要的字的字典(自己建立)
index = 0
for documents in orgdata['title']: #從 csv. 檔中的 JOB_DETAIL 欄位中找尋資料
    seg_list = jieba.analyse.extract_tags(documents, 150) #150 為前150個權重最高的單詞
    #seg_list = jieba.lcut(documents)
    orgdata['seg'].iloc[index] = seg_list
    index += 1
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\happy\AppData\Local\Temp\jieba.cache
# Loading model cost 0.798 seconds.
# Prefix dict has been built successfully.

# %%
jieba.load_userdict('./userdict.txt')
jieba.analyse.set_stop_words('stopwords.txt')
index = 0
for documents in orgdata['title']: #從 csv. 檔中的 JOB_DETAIL 欄位中找尋資料
    seg_list = jieba.analyse.extract_tags(documents, 150) #150 為前150個權重最高的單詞
    #seg_list = jieba.lcut(documents)
    orgdata['seg'].iloc[index] = seg_list
    index += 1

# %%
orgdata['seg']
# Out:
# 0     [Gogoro, foodpanda, 將於, 電動, 機車換, 電系統, 新加坡, 推行,...
# 1                  [團隊, 協作, 微軟, 激似, Notion, 想像, 工具, 推出]
# 2            [生成式, AI, 潛力, 中華電, 客戶, 服務, 應用, 切入, 看好, 有望]
# 3                   [AI, 還在, 中學階段, 未成熟, 童子, 可知, 哪些, 取代]
# 4                      [列印, 首枚, 3D, 發射, 進入, 軌道, 火箭, 成功]
# 5                        [連五升, 總裁, 楊金龍, 半碼, 升息, 意外, 央行]
# 6             [伺服器, 數位, 轉型, 戴爾, 業績, 成長, 裁員, 影響, 發展, 支持]
# 7     [GitHub, GPT, Copilot, 師動口, 開發, 程式, 新版, 支援, 工程...
# 8                [利金, Arm, 調高權, 會聯, 發科, 高通, 已知, 打算, 大幅]
# 9          [瞄準, 醫療, 千億, 商機, 27, 70, 掛牌, 生光, 智慧, 平台, 上市]
# 10                [文生, AI, 繪圖, 直譯, 引熱議, 圖會, 百度, 更新, 快速]
# 11               [半導, 體業, 不景氣, 南韓, 驅動, IC, 美格, 納縮減, 人力]
# 12                       [動盪, 結束, 傳東芝, JIP, 圓收, 購要, 接受]
# 13                    [Siegel, 人們, 比特幣, 信任, 回落, 再次, 重新]
# 14                  [電池類, 股成長, 空間, 高達, 70%, 謹慎, 三家, 看好]
# 15           [鮑爾, 擴表, 000, 貨幣, 無關, Fed, 將續, 升息, 必要, 政策]
# 16         [比爾蓋茲, AI, 時代, 點名, OpenAI, GPT, 成企業, 勝出, 關鍵]
# 17        [拜登, 敵視, 加密貨幣, 價值, 白宮, 報告, 穩定幣, DeFi, 劇烈, 基本]
# 18       [快訊, 瑞銀, UBS, 擬以, 收購, 信貸, 2%, 全盛期, 瑞士, 市值, 不到]
# 19                    [加密貨幣, 金管會, 機關, 中央社, 行政院, 主管, 月底]
# 20    [加持, FTX, 重啟, 傳言, FTT, 大漲, 53%, 1.75, 投行, Jeff...
# 21                    [BitMEX, 創辦, 大轉, 比特幣, 漲至, 央行, 政策]
# 22    [瑞信, 進入, 關鍵, 時刻, UBS, 19, 收購, 協議, 貝萊德, 否認, 競購,...
# 23    [FTX, 重啟, 談判, 投行, Jefferies, 競購方, 接觸, Zhu, Su,...
# 24                        [快訊, 22, 申請, 章破產, 保護, 不足, 正式]
# 25     [ChatGPT, 通過, Google, 三級, 師面試, 500, 萬台幣, 年薪, 工程]
# 26    [FTX, 必讀, 維權, 經驗, Tom, 告訴, 請律師, Steaker, 疑點, 受...
# 27                  [一個, 散戶, 爆倉, 200, 日記, 加密貨幣, 生前, 留下]
# 28                   [下個, 速覽, Lens, 協議, 關注, 項目, 大毛, 值得]
# 29                      [指數連, Fed, 減緩, 比特幣, 萬鎂, 升息, 上攻]
# 30    [Web3, 倡議, HashKey, arkreen, DePIN, 生態, 合作伙伴, ...
# Name: seg, dtype: object

# %%
orgdata.head()
# Out:
#                                    title  \
# 0  Gogoro 與 foodpanda 合作，將於新加坡推行電動機車換電系統
# 1            團隊協作新的想像，微軟推出激似 Notion 的新工具
# 2             看好生成式 AI 潛力，中華電有望從客戶服務切入應用
# 3             童子賢：AI 還在中學階段未成熟，取代哪些產業不可知
# 4                全球首枚 3D 列印火箭成功發射，惜未進入軌道
#
#                                                  seg
# 0  [Gogoro, foodpanda, 將於, 電動, 機車換, 電系統, 新加坡, 推行,...
# 1               [團隊, 協作, 微軟, 激似, Notion, 想像, 工具, 推出]
# 2         [生成式, AI, 潛力, 中華電, 客戶, 服務, 應用, 切入, 看好, 有望]
# 3                [AI, 還在, 中學階段, 未成熟, 童子, 可知, 哪些, 取代]
# 4                   [列印, 首枚, 3D, 發射, 進入, 軌道, 火箭, 成功]

# %% [markdown]
# 詞頻分析

# %%
subdata = orgdata['seg']
subdata_seg_list = subdata.tolist()

flat = [x for sublist in subdata_seg_list for x in sublist]
diction = Counter(flat) # Counter：dict 的子類別，用來計算可雜湊 ( hashable ) 物件的數量

diction_key = pd.DataFrame(diction.keys())
diction_values = pd.DataFrame(diction.values())
df = [diction_key, diction_values]
result = pd.concat(df, axis=1)
result.columns = ['單字', 'freguency']
result
# Out:
#             單字  freguency
# 0       Gogoro          1
# 1    foodpanda          1
# 2           將於          1
# 3           電動          1
# 4          機車換          1
# ..         ...        ...
# 250      DePIN          1
# 251         生態          1
# 252       合作伙伴          1
# 253         落地          1
# 254         香港          1
#
# [255 rows x 2 columns]

# %%
result.describe( ) #可找出出現次數較多的值(捨棄掉過多低次數的較不重要訊息)
# Out:
#         freguency
# count  255.000000
# mean     1.105882
# std      0.387508
# min      1.000000
# 25%      1.000000
# 50%      1.000000
# 75%      1.000000
# max      4.000000

# %%
diction.keys()
# Out:
# dict_keys(['Gogoro', 'foodpanda', '將於', '電動', '機車換', '電系統', '新加坡', '推行', '合作', '團隊', '協作', '微軟', '激似', 'Notion', '想像', '工具', '推出', '生成式', 'AI', '潛力', '中華電', '客戶', '服務', '應用', '切入', '看好', '有望', '還在', '中學階段', '未成熟', '童子', '可知', '哪些', '取代', '列印', '首枚', '3D', '發射', '進入', '軌道', '火箭', '成功', '連五升', '總裁', '楊金龍', '半碼', '升息', '意外', '央行', '伺服器', '數位', '轉型', '戴爾', '業績', '成長', '裁員', '影響', '發展', '支持', 'GitHub', 'GPT', 'Copilot', '師動口', '開發', '程式', '新版', '支援', '工程', '利金', 'Arm', '調高權', '會聯', '發科', '高通', '已知', '打算', '大幅', '瞄準', '醫療', '千億', '商機', '27', '70', '掛牌', '生光', '智慧', '平台', '上市', '文生', '繪圖', '直譯', '引熱議', '圖會', '百度', '更新', '快速', '半導', '體業', '不景氣', '南韓', '驅動', 'IC', '美格', '納縮減', '人力', '動盪', '結束', '傳東芝', 'JIP', '圓收', '購要', '接受', 'Siegel', '人們', '比特幣', '信任', '回落', '再次', '重新', '電池類', '股成長', '空間', '高達', '70%', '謹慎', '三家', '鮑爾', '擴表', '000', '貨幣', '無關', 'Fed', '將續', '必要', '政策', '比爾蓋茲', '時代', '點名', 'OpenAI', '成企業', '勝出', '關鍵', '拜登', '敵視', '加密貨幣', '價值', '白宮', '報告', '穩定幣', 'DeFi', '劇烈', '基本', '快訊', '瑞銀', 'UBS', '擬以', '收購', '信貸', '2%', '全盛期', '瑞士', '市值', '不到', '金管會', '機關', '中央社', '行政院', '主管', '月底', '加持', 'FTX', '重啟', '傳言', 'FTT', '大漲', '53%', '1.75', '投行', 'Jefferies', '傳接觸', '競標者', 'BitMEX', '創辦', '大轉', '漲至', '瑞信', '時刻', '19', '協議', '貝萊德', '否認', '競購', '最晚', '敲定', '談判', '競購方', '接觸', 'Zhu', 'Su', '2.0', '債權人', '機會', '第二次', '22', '申請', '章破產', '保護', '不足', '正式', 'ChatGPT', '通過', 'Google', '三級', '師面試', '500', '萬台幣', '年薪', '必讀', '維權', '經驗', 'Tom', '告訴', '請律師', 'Steaker', '疑點', '受害者', '多久', '自己', '一個', '散戶', '爆倉', '200', '日記', '生前', '留下', '下個', '速覽', 'Lens', '關注', '項目', '大毛', '值得', '指數連', '減緩', '萬鎂', '上攻', 'Web3', '倡議', 'HashKey', 'arkreen', 'DePIN', '生態', '合作伙伴', '落地', '香港'])

# %%
type(diction)
# Out:
# collections.Counter

# %%
# diction

# %% [markdown]
# 文字雲

# %%
from PIL import Image # PIL：影像處理套件
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import numpy as np

mask = np.array(Image.open("black_rectangle.png")) # 想呈現的圖案形狀
font = "C:\Windows\Fonts\mingliu.ttc" # 選取想呈現字體的字體路徑

# 把文字變成圖片(文字雲)
wordcloud = WordCloud(background_color = "white", font_path=font, mask = mask)
wordcloud.generate_from_frequencies(diction)

# 調圖片的大小顯示圖片
plt.figure(figsize=(10,10))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# 備份整理過後的資料

# %%
# 把 dataframe 的資料寫進 csv.檔，和爬蟲的資料寫到 csv.檔是一樣的
orgdata.to_csv("textmining_0323.csv", index=False)
