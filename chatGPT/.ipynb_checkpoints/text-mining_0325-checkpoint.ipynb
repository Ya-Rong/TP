# %%
import jieba
import jieba.analyse
import re
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from collections import Counter

plt.rcParams["font.sans-serif"]='Microsoft JhengHei'

# %%
orgdata = pd.DataFrame(df)

# %%
orgdata['seg'] = ""
orgdata.head()
# Out:
#                                    title seg
# 0  下一隻汽車共享獨角獸 Turo，去年營收成長 59% 營收突破 7 億美元
# 1           別偷 AirPods 耳機，它基本上就是個 AirTag
# 2          IBM 加拿大投資為第一步，美加計劃發展「雙邊半導體走道」
# 3                退休年齡延至 64 歲，引發法國百萬人上街抗議
# 4           污水處理不再昂貴困難，以木材輕鬆去除 80% 染料有毒物

# %%
jieba.analyse.set_stop_words('stopwords.txt') #stopwords 自己不要的字的字典(自己建立)
index = 0
for documents in orgdata['title']: #從 csv. 檔中的 JOB_DETAIL 欄位中找尋資料
    seg_list = jieba.analyse.extract_tags(documents) #150 為前150個權重最高的單詞
    #seg_list = jieba.lcut(documents)
    orgdata['seg'].iloc[index] = seg_list
    index += 1
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\happy\AppData\Local\Temp\jieba.cache
# Loading model cost 2.451 seconds.
# Prefix dict has been built successfully.

# %%
jieba.load_userdict('./userdict.txt')
jieba.analyse.set_stop_words('stopwords.txt')
index = 0
for documents in orgdata['title']: #從 csv. 檔中的 JOB_DETAIL 欄位中找尋資料
    seg_list = jieba.analyse.extract_tags(documents) #150 為前150個權重最高的單詞
    #seg_list = jieba.lcut(documents)
    orgdata['seg'].iloc[index] = seg_list
    index += 1

# %%
orgdata['seg']
# Out:
# 0                      [汽車, 獨角獸, Turo, 59%, 收成, 共享, 突破]
# 1                    [別偷, AirPods, 耳機, AirTag, 基本上, 就是]
# 2             [美加, IBM, 投資為, 計劃, 發展, 雙邊, 半導體, 第一步, 加拿大]
# 3                   [年齡, 64, 引發法, 國百萬人, 抗議, 延至, 上街, 退休]
# 4             [處理, 昂貴, 困難, 80%, 毒物, 去除, 污水, 染料, 木材, 不再]
# 5                 [AirPods, Pro, 將推, USB, 平價版, 沒計畫, 似乎]
# 6                  [風場, 第三座, 離岸, 啟動, 海能, 376MW, 全數, 完工]
# 7                       [徵兆, 發現, 阿茲海默症, 早期, 最新, 眼睛, 研究]
# 8                 [師強, 下個, 信貸, 遭殃, 德意志, 蔓延, 恐慌, 瑞士, 不是]
# 9                         [生產, 傳蘋果, 應商, 碩將, 移出, 印度, 第二]
# 10                         [華府, 不僅, 晶片, 登月, 受挫, 制裁, 取得]
# 11    [爾聯合, 創辨人, 摩爾, Gordon, Moore, 辭世, 享耆, 94, 英特, ...
# 12          [Blue, Origin, 調查, 結果, 預計, 飛行, 今年底, 火箭, 事故]
# 13                                    [美記者, 獲准, 參訪, 境界]
# 14    [Polestar, 擊敗, Model, 3Y, 成為, 德國, 歡迎, 特斯拉, 最受,...
# 15          [Polestar, 擊敗, Model, 成德國, 歡迎, 特斯拉, 最受, 公司]
# 16               [台積, 電總裁, 魏哲家, 400, 2.156, 億元, 市值, 股票]
# 17             [330, 橙燈, 科學園區, 總量, 節水, 10%, 水情, 高雄, 管制]
# 18           [貝佐斯親, Alexa, 無人, 為何, 驚世, 創意, 行不通, 提案, 超市]
# 19                 [台灣產業, 無懼, 台化, 半導體, 帶頭, 衝開, 大國民, 格局]
# 20          [網友產, 生川普, 圖瘋傳, Midjourney, 暫停, 權限, 被捕, 使用]
# 21         [002, 獲頭銜, 14, Google, 最神, 專家, 開發者, 專家群, 揭密]
# 22         [友達, 轉型, 最關鍵, 彭双浪, 2025, 超過, 二成, 面板, 三家, 公司]
# 23                    [生成式, AI, 協助, 系統, 開發, 高盛, 工具, 研究]
# 24                             [電動車, 成長, 隨各種, 資安風險, 快速]
# 25                                 [開發, 機器, 腦波, 技術, 澳洲]
# 26                        [狂想, 科學家, 嚴酷, 晨昏, 交界, 行星, 生命]
# 27    [Ivacy, VPN, 限時, 優惠, 僅需, 解鎖, Netflix, Hulu, 地區...
# 28    [搶電費, 節能, 補助, 商機, 東元, 空調, 出貨, 估年, 成長, 40%, 第三季...
# 29     [曾嘗試, 南韓, OLED, DDIC, 大廠, MagnaChip, 裁員, 私募, 基金]
# 30      [SpaceX, 升級, 星鏈, V2, mini, 版衛星, 進入, 表現, 太空, 不佳]
# 31                   [Micro, LED, 專利, 申請, Apple, Watch]
# 32                            [慧洋, 6.5, 46%, 10.2%, 利率]
# 33         [華碩, 人工智慧, 內視鏡, 輔助, 系統, 強化, 檢出, 大腸癌, 機率, 病灶]
# 34                          [來次, 永豐金, 0.6, 0.2, 七年, 股票]
# 35                  [罕見, 電車, Mullen, 純電超, 中美合作, 代理, 取得]
# 36                   [應付, 中國釋, 放頂, 投資者, 加強, 發展, 晶片, 制裁]
# 37            [俄羅斯, 烏軍敵後作戰, 星鏈, 設備, 開始, 干擾, 遭到, 找到, 方法]
# 38                         [減資, 鼎炫, KY, 辦理, 兩成, 配息, 領回]
# 39    [醫療, 聖幹, 細胞, 新藥, 獲美台, FDA, 進入, 臨床, 里程碑, 二期, 再生...
# 40                  [勾勾, Twitter, Blue, 開放, 訂閱, 節砍, 愚人]
# 41             [93, 基樁, 風場, 動工, 海事, 中能, 完工, 水下, 工程, 正式]
# 42                      [Q3, 庫存, 見底, Trafigura, 銅價, 歷史]
# 43                           [傳蘋果, 將年, 進軍大, 螢幕, 戲院, 類股]
# 44                    [PS5, 銷量, 暴減, 週來, 首輸, Switch, 四成]
# Name: seg, dtype: object

# %%
orgdata.head()
# Out:
#                                    title  \
# 0  下一隻汽車共享獨角獸 Turo，去年營收成長 59% 營收突破 7 億美元
# 1           別偷 AirPods 耳機，它基本上就是個 AirTag
# 2          IBM 加拿大投資為第一步，美加計劃發展「雙邊半導體走道」
# 3                退休年齡延至 64 歲，引發法國百萬人上街抗議
# 4           污水處理不再昂貴困難，以木材輕鬆去除 80% 染料有毒物
#
#                                          seg
# 0           [汽車, 獨角獸, Turo, 59%, 收成, 共享, 突破]
# 1         [別偷, AirPods, 耳機, AirTag, 基本上, 就是]
# 2  [美加, IBM, 投資為, 計劃, 發展, 雙邊, 半導體, 第一步, 加拿大]
# 3        [年齡, 64, 引發法, 國百萬人, 抗議, 延至, 上街, 退休]
# 4  [處理, 昂貴, 困難, 80%, 毒物, 去除, 污水, 染料, 木材, 不再]

# %%
# 定義科技相關詞彙
tech_words = ['人工智慧','機器學習','區塊鏈','物聯網','雲端運算','大數據','虛擬實境','FTX',
              '加密貨幣','比特幣','AI','3D列印','GPT-4','ChatGPT','Copilot','AI 繪圖','半導體',
              'Fed','OpenAPI','GPT','穩定幣','DeFi','BitMEX','SVB','USDC','FDIC','Meta','Web3',
              'NFT','Silvergate','Coinbase','ETH','元宇宙','Metaverse','Clubhouse','Decentralizing',
              'AIGC','Bard','Bing','以太坊','擴增實境','虛擬實境','網路安全' ,'智能合約','AR','VR','3D']
# ,'','','','','','','',''

# %%
# 篩選科技相關詞彙並斷詞
tokens = []
for n in result:
    words = jieba.cut(n)
    for w in words:
        if w in tech_words:
            tokens.append(w)
#             re.match('.*[\u4e00-\u9fa5]+.*', w) and

# %%
print(tokens)
# Out:
# ['比特幣', 'SVB', 'Coinbase', '加密貨幣', '加密貨幣', 'FTX', '比特幣', 'ChatGPT', 'FTX', '比特幣', 'SVB', 'Coinbase', '加密貨幣', '加密貨幣', 'FTX', '比特幣', 'ChatGPT', 'FTX', 'Fed', '比特幣', '加密貨幣', 'NFT', 'NFT', 'USDC', 'ChatGPT', 'FTX', '區塊鏈', 'FTX', 'Fed', 'ETH', 'Coinbase', 'Meta', 'ChatGPT', 'FTX', '人工智慧', '半導體', '半導體', 'AI', '人工智慧']

# %%
import pandas as pd
from collections import Counter

# 創建一個 Python 的 list
# my_list = ["apple", "banana", "apple", "orange", "banana", "grape"]

# 使用 Counter 函數計算詞頻
word_count = Counter(tokens)

# 將字典轉換成 DataFrame
df = pd.DataFrame.from_dict(word_count, orient="index", columns=["frequency"])

# 檢查結果
df
# Out:
#           frequency
# 比特幣               5
# SVB               2
# Coinbase          3
# 加密貨幣              5
# FTX               7
# ChatGPT           4
# Fed               2
# NFT               2
# USDC              1
# 區塊鏈               1
# ETH               1
# Meta              1
# 人工智慧              2
# 半導體               2
# AI                1

# %% [markdown]
# 文字雲

# %%
from PIL import Image # PIL：影像處理套件
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import numpy as np

mask = np.array(Image.open("black_rectangle.png")) # 想呈現的圖案形狀
font = "C:\Windows\Fonts\mingliu.ttc" # 選取想呈現字體的字體路徑

# 把文字變成圖片(文字雲)
wordcloud = WordCloud(background_color = "white", font_path=font, mask = mask)
wordcloud.generate_from_frequencies(word_count)

# 調圖片的大小顯示圖片
plt.figure(figsize=(10,10))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
import pandas as pd 
df = pd.DataFrame(tokens, columns=['word'])
df.head()
# Out:
#        word
# 0       比特幣
# 1       SVB
# 2  Coinbase
# 3      加密貨幣
# 4      加密貨幣

# %%
# 備份
orgdata.to_csv("crawler_0325.csv", index=False)
df.to_csv("crawler_df_0325.csv", index=False)
